# %% [markdown]
# <a href="https://colab.research.google.com/github/ProtossDragoon/ludwig-quickstart/blob/main/notebook/Ludwig.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ludwig AutoML 을 이용한 텍스트 분류

# %% [markdown]
# [데이터셋](http://boston.lti.cs.cmu.edu/classes/95-865-K/HW/HW2/)

# %%
# !pip uninstall -y tensorflow # https://github.com/ludwig-ai/ludwig/issues/2450
# !pip install -q ludwig
# Out:
# Found existing installation: tensorflow 2.9.2
# Uninstalling tensorflow-2.9.2:
#   Successfully uninstalled tensorflow-2.9.2
#      |████████████████████████████████| 636 kB 34.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 90 kB 10.2 MB/s
#      |████████████████████████████████| 25.6 MB 21.3 MB/s
#      |████████████████████████████████| 80 kB 9.3 MB/s
#      |████████████████████████████████| 10.5 MB 60.5 MB/s
#      |████████████████████████████████| 4.7 MB 68.8 MB/s
#      |████████████████████████████████| 409 kB 54.8 MB/s
#      |████████████████████████████████| 182 kB 70.3 MB/s
#      |████████████████████████████████| 6.6 MB 40.9 MB/s
#      |████████████████████████████████| 84 kB 4.5 MB/s
#      |████████████████████████████████| 72 kB 1.3 MB/s
#      |████████████████████████████████| 98 kB 10.3 MB/s
#      |████████████████████████████████| 52 kB 1.4 MB/s
#      |████████████████████████████████| 66 kB 5.6 MB/s
#      |████████████████████████████████| 280 kB 84.0 MB/s
#      |████████████████████████████████| 58 kB 7.2 MB/s
#   Building wheel for ludwig (PEP 517) ... done
#   Building wheel for bootstrapped (setup.py) ... done
#   Building wheel for gpustat (setup.py) ... done
#   Building wheel for pylatex (setup.py) ... done

# %%
# !wget https://raw.githubusercontent.com/ProtossDragoon/ludwig-quickstart/main/config.yaml
# !wget https://raw.githubusercontent.com/ProtossDragoon/ludwig-quickstart/main/reuters-allcats.csv
# Out:
# --2022-12-18 12:35:28--  https://raw.githubusercontent.com/ProtossDragoon/ludwig-quickstart/main/config.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 176 [text/plain]
# Saving to: ‘config.yaml’
#
# config.yaml         100%[===================>]     176  --.-KB/s    in 0s
#
# 2022-12-18 12:35:28 (8.12 MB/s) - ‘config.yaml’ saved [176/176]
#
# --2022-12-18 12:35:28--  https://raw.githubusercontent.com/ProtossDragoon/ludwig-quickstart/main/reuters-allcats.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3381488 (3.2M) [text/plain]
# Saving to: ‘reuters-allcats.csv’
#
# reuters-allcats.csv 100%[===================>]   3.22M  --.-KB/s    in 0.02s
#
# 2022-12-18 12:35:28 (189 MB/s) - ‘reuters-allcats.csv’ saved [3381488/3381488]

# %%
# !ludwig experiment \
  --dataset reuters-allcats.csv \
  --config config.yaml
# Out:
# ███████████████████████
# █ █ █ █  ▜█ █ █ █ █   █
# █ █ █ █ █ █ █ █ █ █ ███
# █ █   █ █ █ █ █ █ █ ▌ █
# █ █████ █ █ █ █ █ █ █ █
# █     █  ▟█     █ █   █
# ███████████████████████
# ludwig v0.6.4 - Experiment
#
#
# ╒════════════════════════╕
# │ EXPERIMENT DESCRIPTION │
# ╘════════════════════════╛
#
# ╒══════════════════╤═════════════════════════════════════════════════════════════════════════════╕
# │ Experiment name  │ experiment                                                                  │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────┤
# │ Model name       │ run                                                                         │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────┤
# │ Output directory │ /content/results/experiment_run                                             │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────┤
# │ ludwig_version   │ '0.6.4'                                                                     │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────┤
# │ command          │ ('/usr/local/bin/ludwig experiment --dataset reuters-allcats.csv --config ' │
# │                  │  'config.yaml')                                                             │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────┤
# │ random_seed      │ 42                                                                          │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────┤
# │ dataset          │ 'reuters-allcats.csv'                                                       │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────┤
# │ data_format      │ 'csv'                                                                       │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────┤
# │ torch_version    │ '1.13.0+cu116'                                                              │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────┤
# │ compute          │ {'gpu_type': 'Tesla T4', 'gpus_per_node': 1, 'num_nodes': 1}                │
# ╘══════════════════╧═════════════════════════════════════════════════════════════════════════════╛
#
# ╒═══════════════╕
# │ LUDWIG CONFIG │
# ╘═══════════════╛
#
# {   'combiner': {   'activation': 'relu',
#                     'bias_initializer': 'zeros',
#                     'dropout': 0.0,
#                     'fc_layers': None,
#                     'flatten_inputs': False,
#                     'norm': None,
#                     'norm_params': None,
#                     'num_fc_layers': 0,
#                     'output_size': 256,
#                     'residual': False,
#                     'type': 'concat',
#                     'use_bias': True,
#                     'weights_initializer': 'xavier_uniform'},
#     'defaults': {   'audio': {   'preprocessing': {   'audio_file_length_limit_in_s': 7.5,
#                                                       'computed_fill_value': None,
#                                                       'fill_value': None,
#                                                       'in_memory': True,
#                                                       'missing_value_strategy': 'bfill',
#                                                       'norm': None,
#                                                       'num_fft_points': None,
#                                                       'num_filter_bands': 80,
#                                                       'padding_value': 0.0,
#                                                       'type': 'fbank',
#                                                       'window_length_in_s': 0.04,
#                                                       'window_shift_in_s': 0.02,
#                                                       'window_type': 'hamming'}},
#                     'bag': {   'preprocessing': {   'computed_fill_value': '<UNK>',
#                                                     'fill_value': '<UNK>',
#                                                     'lowercase': False,
#                                                     'missing_value_strategy': 'fill_with_const',
#                                                     'most_common': 10000,
#                                                     'tokenizer': 'space'}},
#                     'binary': {   'preprocessing': {   'computed_fill_value': None,
#                                                        'fallback_true_label': None,
#                                                        'fill_value': None,
#                                                        'missing_value_strategy': 'fill_with_false'}},
#                     'category': {   'preprocessing': {   'computed_fill_value': '<UNK>',
#                                                          'fill_value': '<UNK>',
#                                                          'lowercase': False,
#                                                          'missing_value_strategy': 'fill_with_const',
#                                                          'most_common': 10000}},
#                     'date': {   'preprocessing': {   'computed_fill_value': '',
#                                                      'datetime_format': None,
#                                                      'fill_value': '',
#                                                      'missing_value_strategy': 'fill_with_const'}},
#                     'h3': {   'preprocessing': {   'computed_fill_value': 576495936675512319,
#                                                    'fill_value': 576495936675512319,
#                                                    'missing_value_strategy': 'fill_with_const'}},
#                     'image': {   'preprocessing': {   'computed_fill_value': None,
#                                                       'fill_value': None,
#                                                       'height': None,
#                                                       'in_memory': True,
#                                                       'infer_image_dimensions': True,
#                                                       'infer_image_max_height': 256,
#                                                       'infer_image_max_width': 256,
#                                                       'infer_image_num_channels': True,
#                                                       'infer_image_sample_size': 100,
#                                                       'missing_value_strategy': 'bfill',
#                                                       'num_channels': None,
#                                                       'num_processes': 1,
#                                                       'resize_method': 'interpolate',
#                                                       'scaling': 'pixel_normalization',
#                                                       'width': None}},
#                     'number': {   'preprocessing': {   'computed_fill_value': 0.0,
#                                                        'fill_value': 0.0,
#                                                        'missing_value_strategy': 'fill_with_const',
#                                                        'normalization': None}},
#                     'sequence': {   'preprocessing': {   'computed_fill_value': '<UNK>',
#                                                          'fill_value': '<UNK>',
#                                                          'lowercase': False,
#                                                          'max_sequence_length': 256,
#                                                          'missing_value_strategy': 'fill_with_const',
#                                                          'most_common': 20000,
#                                                          'padding': 'right',
#                                                          'padding_symbol': '<PAD>',
#                                                          'tokenizer': 'space',
#                                                          'unknown_symbol': '<UNK>',
#                                                          'vocab_file': None}},
#                     'set': {   'preprocessing': {   'computed_fill_value': '<UNK>',
#                                                     'fill_value': '<UNK>',
#                                                     'lowercase': False,
#                                                     'missing_value_strategy': 'fill_with_const',
#                                                     'most_common': 10000,
#                                                     'tokenizer': 'space'}},
#                     'text': {   'preprocessing': {   'computed_fill_value': '<UNK>',
#                                                      'fill_value': '<UNK>',
#                                                      'lowercase': True,
#                                                      'max_sequence_length': 256,
#                                                      'missing_value_strategy': 'fill_with_const',
#                                                      'most_common': 20000,
#                                                      'padding': 'right',
#                                                      'padding_symbol': '<PAD>',
#                                                      'pretrained_model_name_or_path': None,
#                                                      'tokenizer': 'space_punct',
#                                                      'unknown_symbol': '<UNK>',
#                                                      'vocab_file': None}},
#                     'timeseries': {   'preprocessing': {   'computed_fill_value': '',
#                                                            'fill_value': '',
#                                                            'missing_value_strategy': 'fill_with_const',
#                                                            'padding': 'right',
#                                                            'padding_value': 0.0,
#                                                            'timeseries_length_limit': 256,
#                                                            'tokenizer': 'space'}},
#                     'vector': {   'preprocessing': {   'computed_fill_value': '',
#                                                        'fill_value': '',
#                                                        'missing_value_strategy': 'fill_with_const',
#                                                        'vector_size': None}}},
#     'input_features': [   {   'column': 'text',
#                               'encoder': {   'activation': 'relu',
#                                              'bias_initializer': 'zeros',
#                                              'conv_layers': None,
#                                              'dropout': 0.0,
#                                              'embedding_size': 256,
#                                              'embeddings_on_cpu': False,
#                                              'embeddings_trainable': True,
#                                              'fc_layers': None,
#                                              'filter_size': 3,
#                                              'max_sequence_length': None,
#                                              'norm': None,
#                                              'norm_params': None,
#                                              'num_conv_layers': None,
#                                              'num_fc_layers': None,
#                                              'num_filters': 256,
#                                              'output_size': 256,
#                                              'pool_function': 'max',
#                                              'pool_size': None,
#                                              'pretrained_embeddings': None,
#                                              'reduce_output': 'sum',
#                                              'representation': 'dense',
#                                              'should_embed': True,
#                                              'type': 'parallel_cnn',
#                                              'use_bias': True,
#                                              'vocab': None,
#                                              'weights_initializer': 'xavier_uniform'},
#                               'name': 'text',
#                               'preprocessing': {   'computed_fill_value': '<UNK>',
#                                                    'fill_value': '<UNK>',
#                                                    'lowercase': True,
#                                                    'max_sequence_length': 256,
#                                                    'missing_value_strategy': 'fill_with_const',
#                                                    'most_common': 20000,
#                                                    'padding': 'right',
#                                                    'padding_symbol': '<PAD>',
#                                                    'pretrained_model_name_or_path': None,
#                                                    'tokenizer': 'space_punct',
#                                                    'unknown_symbol': '<UNK>',
#                                                    'vocab_file': None},
#                               'proc_column': 'text_mZFLky',
#                               'tied': None,
#                               'type': 'text'}],
#     'ludwig_version': '0.6.4',
#     'model_type': 'ecd',
#     'output_features': [   {   'calibration': False,
#                                'column': 'class',
#                                'decoder': {   'bias_initializer': 'zeros',
#                                               'fc_activation': 'relu',
#                                               'fc_bias_initializer': 'zeros',
#                                               'fc_dropout': 0.0,
#                                               'fc_layers': None,
#                                               'fc_norm': None,
#                                               'fc_norm_params': None,
#                                               'fc_output_size': 256,
#                                               'fc_use_bias': True,
#                                               'fc_weights_initializer': 'xavier_uniform',
#                                               'input_size': None,
#                                               'num_classes': None,
#                                               'num_fc_layers': 0,
#                                               'type': 'classifier',
#                                               'use_bias': True,
#                                               'weights_initializer': 'xavier_uniform'},
#                                'dependencies': [],
#                                'input_size': None,
#                                'loss': {   'class_similarities_temperature': 0,
#                                            'class_weights': None,
#                                            'confidence_penalty': 0.0,
#                                            'robust_lambda': 0,
#                                            'type': 'softmax_cross_entropy',
#                                            'weight': 1.0},
#                                'name': 'class',
#                                'num_classes': None,
#                                'preprocessing': {   'computed_fill_value': '<UNK>',
#                                                     'fill_value': '<UNK>',
#                                                     'lowercase': False,
#                                                     'missing_value_strategy': 'drop_row',
#                                                     'most_common': 10000},
#                                'proc_column': 'class_mZFLky',
#                                'reduce_dependencies': 'sum',
#                                'reduce_input': 'sum',
#                                'top_k': 3,
#                                'type': 'category'}],
#     'preprocessing': {   'oversample_minority': None,
#                          'sample_ratio': 1.0,
#                          'split': {   'probabilities': [0.7, 0.1, 0.2],
#                                       'type': 'random'},
#                          'undersample_majority': None},
#     'trainer': {   'batch_size': 128,
#                    'checkpoints_per_epoch': 0,
#                    'decay': False,
#                    'decay_rate': 0.96,
#                    'decay_steps': 10000,
#                    'early_stop': 5,
#                    'epochs': 100,
#                    'eval_batch_size': None,
#                    'evaluate_training_set': True,
#                    'gradient_clipping': {   'clipglobalnorm': 0.5,
#                                             'clipnorm': None,
#                                             'clipvalue': None},
#                    'increase_batch_size_eval_metric': 'loss',
#                    'increase_batch_size_eval_split': 'training',
#                    'increase_batch_size_on_plateau': 0,
#                    'increase_batch_size_on_plateau_patience': 5,
#                    'increase_batch_size_on_plateau_rate': 2.0,
#                    'learning_rate': 0.001,
#                    'learning_rate_scaling': 'linear',
#                    'learning_rate_warmup_epochs': 1.0,
#                    'max_batch_size': 1099511627776,
#                    'optimizer': {   'amsgrad': False,
#                                     'betas': (0.9, 0.999),
#                                     'eps': 1e-08,
#                                     'lr': 0.001,
#                                     'type': 'adam',
#                                     'weight_decay': 0.0},
#                    'reduce_learning_rate_eval_metric': 'loss',
#                    'reduce_learning_rate_eval_split': 'training',
#                    'reduce_learning_rate_on_plateau': 0.0,
#                    'reduce_learning_rate_on_plateau_patience': 5,
#                    'reduce_learning_rate_on_plateau_rate': 0.5,
#                    'regularization_lambda': 0.0,
#                    'regularization_type': 'l2',
#                    'should_shuffle': True,
#                    'staircase': False,
#                    'steps_per_checkpoint': 0,
#                    'train_steps': None,
#                    'type': 'trainer',
#                    'validation_field': 'combined',
#                    'validation_metric': 'loss'}}
#
# ╒═══════════════╕
# │ PREPROCESSING │
# ╘═══════════════╛
#
# Using full raw dataset, no hdf5 and json file with the same name have been found
# Building dataset (it may take a while)
# Building dataset: DONE
# Writing preprocessed training set cache
# Writing preprocessed test set cache
# Writing preprocessed validation set cache
# Writing train set metadata
#
# Dataset Statistics
# ╒════════════╤═══════════════╤════════════════════╕
# │ Dataset    │   Size (Rows) │ Size (In Memory)   │
# ╞════════════╪═══════════════╪════════════════════╡
# │ Training   │          2855 │ 315.18 Kb          │
# ├────────────┼───────────────┼────────────────────┤
# │ Validation │           407 │ 45.04 Kb           │
# ├────────────┼───────────────┼────────────────────┤
# │ Test       │           817 │ 90.28 Kb           │
# ╘════════════╧═══════════════╧════════════════════╛
#
# ╒═══════╕
# │ MODEL │
# ╘═══════╛
#
# Warnings and other logs:
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py:309: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return F.conv1d(input, weight, bias, self.stride,
#
# ╒══════════╕
# │ TRAINING │
# ╘══════════╛
#
# Training for 2300 step(s), approximately 100 epoch(s).
# Early stopping policy: 5 round(s) of evaluation, or 115 step(s), approximately 5 epoch(s).
#
# Starting with step 0, epoch: 0
# Training:   1% 21/2300 [00:08<03:28, 10.94it/s]
# Running evaluation for step: 23, epoch: 0
# Evaluation train: 100% 23/23 [00:00<00:00, 40.22it/s]
# Evaluation valid: 100% 4/4 [00:00<00:00, 52.18it/s]
# Evaluation test : 100% 7/7 [00:00<00:00, 44.37it/s]
# ╒════════════╤════════╤════════════╤═════════════╕
# │ class      │   loss │   accuracy │   hits_at_k │
# ╞════════════╪════════╪════════════╪═════════════╡
# │ train      │ 0.6677 │     0.7916 │      0.9828 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ validation │ 0.6419 │     0.7445 │      0.9853 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ test       │ 0.7115 │     0.7368 │      0.9829 │
# ╘════════════╧════════╧════════════╧═════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.6677 │
# ├────────────┼────────┤
# │ validation │ 0.6419 │
# ├────────────┼────────┤
# │ test       │ 0.7115 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved.
#
# Training:   2% 44/2300 [00:10<02:33, 14.69it/s]
# Running evaluation for step: 46, epoch: 1
# Evaluation train: 100% 23/23 [00:00<00:00, 42.02it/s]
# Evaluation valid: 100% 4/4 [00:00<00:00, 51.48it/s]
# Evaluation test : 100% 7/7 [00:00<00:00, 44.21it/s]
# ╒════════════╤════════╤════════════╤═════════════╕
# │ class      │   loss │   accuracy │   hits_at_k │
# ╞════════════╪════════╪════════════╪═════════════╡
# │ train      │ 0.1192 │     0.9671 │      0.9926 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ validation │ 0.2445 │     0.9165 │      0.9803 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ test       │ 0.1922 │     0.9302 │      0.9927 │
# ╘════════════╧════════╧════════════╧═════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.1192 │
# ├────────────┼────────┤
# │ validation │ 0.2445 │
# ├────────────┼────────┤
# │ test       │ 0.1922 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved.
#
# Training:   3% 67/2300 [00:13<02:32, 14.65it/s]
# Running evaluation for step: 69, epoch: 2
# Evaluation train: 100% 23/23 [00:00<00:00, 41.74it/s]
# Evaluation valid: 100% 4/4 [00:00<00:00, 51.16it/s]
# Evaluation test : 100% 7/7 [00:00<00:00, 45.02it/s]
# ╒════════════╤════════╤════════════╤═════════════╕
# │ class      │   loss │   accuracy │   hits_at_k │
# ╞════════════╪════════╪════════════╪═════════════╡
# │ train      │ 0.0397 │     0.9874 │      0.9958 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ validation │ 0.2085 │     0.9386 │      0.9828 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ test       │ 0.1941 │     0.9535 │      0.9804 │
# ╘════════════╧════════╧════════════╧═════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0397 │
# ├────────────┼────────┤
# │ validation │ 0.2085 │
# ├────────────┼────────┤
# │ test       │ 0.1941 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved.
#
# Training:   4% 90/2300 [00:16<02:27, 14.95it/s]
# Running evaluation for step: 92, epoch: 3
# Evaluation train: 100% 23/23 [00:00<00:00, 42.14it/s]
# Evaluation valid: 100% 4/4 [00:00<00:00, 48.92it/s]
# Evaluation test : 100% 7/7 [00:00<00:00, 44.25it/s]
# ╒════════════╤════════╤════════════╤═════════════╕
# │ class      │   loss │   accuracy │   hits_at_k │
# ╞════════════╪════════╪════════════╪═════════════╡
# │ train      │ 0.0307 │     0.9916 │      0.9989 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ validation │ 0.3977 │     0.9214 │      0.9705 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ test       │ 0.3893 │     0.9192 │      0.9657 │
# ╘════════════╧════════╧════════════╧═════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0307 │
# ├────────────┼────────┤
# │ validation │ 0.3977 │
# ├────────────┼────────┤
# │ test       │ 0.3893 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 23 step(s) ago.
#
# Training:   5% 113/2300 [00:18<02:25, 15.02it/s]
# Running evaluation for step: 115, epoch: 4
# Evaluation train: 100% 23/23 [00:00<00:00, 42.00it/s]
# Evaluation valid: 100% 4/4 [00:00<00:00, 51.94it/s]
# Evaluation test : 100% 7/7 [00:00<00:00, 44.60it/s]
# ╒════════════╤════════╤════════════╤═════════════╕
# │ class      │   loss │   accuracy │   hits_at_k │
# ╞════════════╪════════╪════════════╪═════════════╡
# │ train      │ 0.0215 │     0.9944 │      0.9982 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ validation │ 0.4487 │     0.9386 │      0.9705 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ test       │ 0.4708 │     0.9315 │      0.9657 │
# ╘════════════╧════════╧════════════╧═════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0215 │
# ├────────────┼────────┤
# │ validation │ 0.4487 │
# ├────────────┼────────┤
# │ test       │ 0.4708 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 46 step(s) ago.
#
# Training:   6% 136/2300 [00:21<02:23, 15.05it/s]
# Running evaluation for step: 138, epoch: 5
# Evaluation train: 100% 23/23 [00:00<00:00, 41.90it/s]
# Evaluation valid: 100% 4/4 [00:00<00:00, 49.86it/s]
# Evaluation test : 100% 7/7 [00:00<00:00, 44.48it/s]
# ╒════════════╤════════╤════════════╤═════════════╕
# │ class      │   loss │   accuracy │   hits_at_k │
# ╞════════════╪════════╪════════════╪═════════════╡
# │ train      │ 0.0523 │     0.9877 │      0.9989 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ validation │ 1.0519 │     0.8943 │      0.9656 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ test       │ 1.2170 │     0.8886 │      0.9535 │
# ╘════════════╧════════╧════════════╧═════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0523 │
# ├────────────┼────────┤
# │ validation │ 1.0519 │
# ├────────────┼────────┤
# │ test       │ 1.2170 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 69 step(s) ago.
#
# Training:   7% 159/2300 [00:23<02:22, 15.05it/s]
# Running evaluation for step: 161, epoch: 6
# Evaluation train: 100% 23/23 [00:00<00:00, 41.74it/s]
# Evaluation valid: 100% 4/4 [00:00<00:00, 49.62it/s]
# Evaluation test : 100% 7/7 [00:00<00:00, 44.46it/s]
# ╒════════════╤════════╤════════════╤═════════════╕
# │ class      │   loss │   accuracy │   hits_at_k │
# ╞════════════╪════════╪════════════╪═════════════╡
# │ train      │ 0.0080 │     0.9989 │      1.0000 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ validation │ 0.7630 │     0.9312 │      0.9877 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ test       │ 0.6729 │     0.9388 │      0.9914 │
# ╘════════════╧════════╧════════════╧═════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0080 │
# ├────────────┼────────┤
# │ validation │ 0.7630 │
# ├────────────┼────────┤
# │ test       │ 0.6729 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 92 step(s) ago.
#
# Training:   8% 182/2300 [00:26<02:21, 14.98it/s]
# Running evaluation for step: 184, epoch: 7
# Evaluation train: 100% 23/23 [00:00<00:00, 41.61it/s]
# Evaluation valid: 100% 4/4 [00:00<00:00, 50.34it/s]
# Evaluation test : 100% 7/7 [00:00<00:00, 43.99it/s]
# ╒════════════╤════════╤════════════╤═════════════╕
# │ class      │   loss │   accuracy │   hits_at_k │
# ╞════════════╪════════╪════════════╪═════════════╡
# │ train      │ 0.0108 │     0.9961 │      1.0000 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ validation │ 0.9880 │     0.9238 │      0.9730 │
# ├────────────┼────────┼────────────┼─────────────┤
# │ test       │ 1.1372 │     0.9192 │      0.9829 │
# ╘════════════╧════════╧════════════╧═════════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0108 │
# ├────────────┼────────┤
# │ validation │ 0.9880 │
# ├────────────┼────────┤
# │ test       │ 1.1372 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 115 step(s) ago.
#
#
# EARLY STOPPING due to lack of validation improvement. It has been 115 step(s) since last validation improvement.
#
# Training:   8% 184/2300 [00:27<05:15,  6.70it/s]
#
# ╒═════════════════╕
# │ TRAINING REPORT │
# ╘═════════════════╛
#
# ╒══════════════════════════════╤═════════════════════╕
# │ Validation feature           │ combined            │
# ├──────────────────────────────┼─────────────────────┤
# │ Validation metric            │ loss                │
# ├──────────────────────────────┼─────────────────────┤
# │ Best model step              │ 69                  │
# ├──────────────────────────────┼─────────────────────┤
# │ Best model epoch             │ 3                   │
# ├──────────────────────────────┼─────────────────────┤
# │ Best model's validation loss │ 0.20852018892765045 │
# ├──────────────────────────────┼─────────────────────┤
# │ Best model's test loss       │ 0.19414670765399933 │
# ╘══════════════════════════════╧═════════════════════╛
#
# Finished: experiment_run
# Saved to: /content/results/experiment_run
#
# ╒══════════╕
# │ FINISHED │
# ╘══════════╛
#
# Evaluation: 100% 7/7 [00:00<00:00, 43.73it/s]
#
# ===== class =====
# accuracy: 0.9534883499145508
# hits_at_k: 0.9804161787033081
# loss: 0.19414670765399933
# overall_stats: { 'avg_f1_score_macro': 0.6649553390863002,
#   'avg_f1_score_micro': 0.9534883720930233,
#   'avg_f1_score_weighted': 0.9510076641202939,
#   'avg_precision_macro': 0.8125972438319627,
#   'avg_precision_micro': 0.9534883720930233,
#   'avg_precision_weighted': 0.9534883720930233,
#   'avg_recall_macro': 0.6384567430262643,
#   'avg_recall_micro': 0.9534883720930233,
#   'avg_recall_weighted': 0.9534883720930233,
#   'kappa_score': 0.9264474890604677,
#   'token_accuracy': 0.9534883720930233}
# per_class_stats: {Neg-: {   'accuracy': 0.9571603427172583,
#     'f1_score': 0.9566294919454771,
#     'fall_out': 0.054892601431980936,
#     'false_discovery_rate': 0.05623471882640585,
#     'false_negative_rate': 0.03015075376884424,
#     'false_negatives': 12,
#     'false_omission_rate': 0.02941176470588236,
#     'false_positive_rate': 0.054892601431980936,
#     'false_positives': 23,
#     'hit_rate': 0.9698492462311558,
#     'informedness': 0.9149566447991748,
#     'markedness': 0.9143535164677119,
#     'matthews_correlation_coefficient': 0.914655030920196,
#     'miss_rate': 0.03015075376884424,
#     'negative_predictive_value': 0.9705882352941176,
#     'positive_predictive_value': 0.9437652811735942,
#     'precision': 0.9437652811735942,
#     'recall': 0.9698492462311558,
#     'sensitivity': 0.9698492462311558,
#     'specificity': 0.9451073985680191,
#     'true_negative_rate': 0.9451073985680191,
#     'true_negatives': 396,
#     'true_positive_rate': 0.9698492462311558,
#     'true_positives': 386},
#   Pos-earn: {   'accuracy': 0.988984088127295,
#     'f1_score': 0.9807280513918629,
#     'fall_out': 0.0034423407917383297,
#     'false_discovery_rate': 0.008658008658008698,
#     'false_negative_rate': 0.029661016949152574,
#     'false_negatives': 7,
#     'false_omission_rate': 0.011945392491467532,
#     'false_positive_rate': 0.0034423407917383297,
#     'false_positives': 2,
#     'hit_rate': 0.9703389830508474,
#     'informedness': 0.9668966422591092,
#     'markedness': 0.9793965988505238,
#     'matthews_correlation_coefficient': 0.973126550284475,
#     'miss_rate': 0.029661016949152574,
#     'negative_predictive_value': 0.9880546075085325,
#     'positive_predictive_value': 0.9913419913419913,
#     'precision': 0.9913419913419913,
#     'recall': 0.9703389830508474,
#     'sensitivity': 0.9703389830508474,
#     'specificity': 0.9965576592082617,
#     'true_negative_rate': 0.9965576592082617,
#     'true_negatives': 579,
#     'true_positive_rate': 0.9703389830508474,
#     'true_positives': 229},
#   Pos-acq: {   'accuracy': 0.9767441860465116,
#     'f1_score': 0.9432835820895523,
#     'fall_out': 0.01538461538461533,
#     'false_discovery_rate': 0.059523809523809534,
#     'false_negative_rate': 0.053892215568862256,
#     'false_negatives': 9,
#     'false_omission_rate': 0.013867488443759624,
#     'false_positive_rate': 0.01538461538461533,
#     'false_positives': 10,
#     'hit_rate': 0.9461077844311377,
#     'informedness': 0.9307231690465225,
#     'markedness': 0.9266087020324307,
#     'matthews_correlation_coefficient': 0.928663656886447,
#     'miss_rate': 0.053892215568862256,
#     'negative_predictive_value': 0.9861325115562404,
#     'positive_predictive_value': 0.9404761904761905,
#     'precision': 0.9404761904761905,
#     'recall': 0.9461077844311377,
#     'sensitivity': 0.9461077844311377,
#     'specificity': 0.9846153846153847,
#     'true_negative_rate': 0.9846153846153847,
#     'true_negatives': 640,
#     'true_positive_rate': 0.9461077844311377,
#     'true_positives': 158},
#   Pos-coffee: {   'accuracy': 0.9902080783353733,
#     'f1_score': 0.19999999999999998,
#     'fall_out': 0.0,
#     'false_discovery_rate': 0.0,
#     'false_negative_rate': 0.8888888888888888,
#     'false_negatives': 8,
#     'false_omission_rate': 0.009803921568627416,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0.1111111111111111,
#     'informedness': 0.11111111111111116,
#     'markedness': 0.9901960784313726,
#     'matthews_correlation_coefficient': 0.3316953217824676,
#     'miss_rate': 0.8888888888888888,
#     'negative_predictive_value': 0.9901960784313726,
#     'positive_predictive_value': 1.0,
#     'precision': 1.0,
#     'recall': 0.1111111111111111,
#     'sensitivity': 0.1111111111111111,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 808,
#     'true_positive_rate': 0.1111111111111111,
#     'true_positives': 1},
#   Pos-gold: {   'accuracy': 0.9987760097919217,
#     'f1_score': 0.9090909090909091,
#     'fall_out': 0.0,
#     'false_discovery_rate': 0.0,
#     'false_negative_rate': 0.16666666666666663,
#     'false_negatives': 1,
#     'false_omission_rate': 0.0012315270935960854,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0.8333333333333334,
#     'informedness': 0.8333333333333335,
#     'markedness': 0.9987684729064039,
#     'matthews_correlation_coefficient': 0.9123086433632736,
#     'miss_rate': 0.16666666666666663,
#     'negative_predictive_value': 0.9987684729064039,
#     'positive_predictive_value': 1.0,
#     'precision': 1.0,
#     'recall': 0.8333333333333334,
#     'sensitivity': 0.8333333333333334,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 811,
#     'true_positive_rate': 0.8333333333333334,
#     'true_positives': 5},
#   Pos-housing: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 817,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   Pos-heat: {   'accuracy': 0.9951040391676866,
#     'f1_score': 0,
#     'fall_out': 0.003676470588235281,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 1,
#     'false_omission_rate': 0.0012285012285012664,
#     'false_positive_rate': 0.003676470588235281,
#     'false_positives': 3,
#     'hit_rate': 0.0,
#     'informedness': -0.003676470588235281,
#     'markedness': -0.0012285012285012664,
#     'matthews_correlation_coefficient': -0.002125217314581192,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 0.9987714987714987,
#     'positive_predictive_value': 0.0,
#     'precision': 0.0,
#     'recall': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.9963235294117647,
#     'true_negative_rate': 0.9963235294117647,
#     'true_negatives': 813,
#     'true_positive_rate': 0.0,
#     'true_positives': 0}}
# Saved to: /content/results/experiment_run
