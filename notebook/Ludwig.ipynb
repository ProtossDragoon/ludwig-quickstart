# %% [markdown]
# <a href="https://colab.research.google.com/github/ProtossDragoon/ludwig-quickstart/blob/main/notebook/Ludwig.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ludwig AutoML 을 이용한 텍스트 분류

# %% [markdown]
# [데이터셋](http://boston.lti.cs.cmu.edu/classes/95-865-K/HW/HW2/)

# %%
# !pip uninstall -y tensorflow # https://github.com/ludwig-ai/ludwig/issues/2450
# !pip install -q ludwig==0.6.4
# Out:
# WARNING: Skipping tensorflow as it is not installed.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 636.2/636.2 kB 13.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 28.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 49.7 MB/s eta 0:00:00
# ...

# %%
# !wget https://raw.githubusercontent.com/ProtossDragoon/ludwig-quickstart/main/config.yaml
# !wget https://raw.githubusercontent.com/ProtossDragoon/ludwig-quickstart/main/reuters-allcats.csv
# Out:
# --2023-07-12 02:49:21--  https://raw.githubusercontent.com/ProtossDragoon/ludwig-quickstart/main/config.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 176 [text/plain]
# Saving to: ‘config.yaml.1’
#
# config.yaml.1       100%[===================>]     176  --.-KB/s    in 0s
#
# 2023-07-12 02:49:22 (9.85 MB/s) - ‘config.yaml.1’ saved [176/176]
#
# --2023-07-12 02:49:22--  https://raw.githubusercontent.com/ProtossDragoon/ludwig-quickstart/main/reuters-allcats.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !ludwig experiment \
  --dataset reuters-allcats.csv \
  --config config.yaml
# Out:
# ███████████████████████
# █ █ █ █  ▜█ █ █ █ █   █
# █ █ █ █ █ █ █ █ █ █ ███
# █ █   █ █ █ █ █ █ █ ▌ █
# █ █████ █ █ █ █ █ █ █ █
# █     █  ▟█     █ █   █
# ███████████████████████
# ludwig v0.6.4 - Experiment
#
#
# ╒════════════════════════╕
# │ EXPERIMENT DESCRIPTION │
# ╘════════════════════════╛
#
# ╒══════════════════╤═════════════════════════════════════════════════════════════════════════════╕
# │ Experiment name  │ experiment                                                                  │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────┤
# │ Model name       │ run                                                                         │
# ├──────────────────┼─────────────────────────────────────────────────────────────────────────────┤
# │ Output directory │ /content/results/experiment_run_0                                           │
# ...
